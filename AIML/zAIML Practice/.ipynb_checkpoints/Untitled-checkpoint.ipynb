# %%
import numpy as np

# %%
li = [['A', 0.12], ['B', 0.16], ['A', 0.17]]
k=3
ans = {
    'A' : 0,
    'B' : 0
}

for i in range(k):
    ans[li[i][0]] += 1

ans
# Out:
# {'A': 2, 'B': 1}

# %%
max(ans, key=ans.get)
# Out:
# 'A'
